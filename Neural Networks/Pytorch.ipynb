# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import *
from torch.utils.data import Dataset
from torch.utils.data import Dataset, TensorDataset
from torch.utils.data import DataLoader
from torch.autograd import Variable

# %%
class NN(nn.Module):
    def __init__(self, C_in, C_out, widths, Layers, act_func, w_initilization):
        super(NN, self).__init__()
        
        layers=[]
        self.w_initilization=w_initilization
        
        for i in range(Layers):
            if i == 0:
                 layers += [nn.Linear(C_in, widths)]
            elif i == Layers - 1:
                 layers += [nn.Linear(widths, C_out)]
            else:
                 layers += [nn.Linear(widths, widths)]
                    
            #try two activation functions:"tanh" and "RELU"
            if act == 'relu':
                layers += [nn.ReLU()]
            else:
                layers += [nn.Tanh()]
            
        self.model = nn.Sequential(*layers)
        self.model.apply(self.initial_w)
        
    def forward(self, x):
            out = self.model(x)
            return out
        
    #For "tanh",use the 'Xavier' initialization; and for"RELU", use the "he" initialization.
    def initial_w(self, m):
            print(m)
            if type(m) == nn.Linear:
                if self.w_initilization == 'he':
                    nn.init.kaiming_uniform_(m.weight, mode='fan_in', nonlinearity='relu')
                else:
                     nn.init.xavier_uniform_(m.weight)
                        
            #self.model = nn.Sequential(*layers)
            #self.model.apply(self.initial_w)

# %%
def train(model, optimizer, criterion, data_loader, epoch):
    model.train()
    total_loss = 0
    optimizer.zero_grad()

    for batch_idx, (data,target) in enumerate(data_loader):
        data, target = Variable(data), Variable(target)
        output = model(data)
        loss = criterion(output, target)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    return total_loss / (batch_idx+1)

# %%
def test(model, data_loader, epoch):
    model.eval()
    total_loss = 0

    with torch.no_grad():
        
        for batch_idx, (data,target) in enumerate(data_loader):
                data, target = Variable(data), Variable(target)
                output = model(data)

                total_loss += F.cross_entropy(output, target)

    
    return total_loss/ (batch_idx + 1)

# %%
#Load data and processing

# %%
train_df = pd.read_csv("train.csv", header=None)
x_train= np.array(train_df.iloc[:,:-1])
y_train = np.array(train_df.iloc[:,-1])

test_df = pd.read_csv("test.csv", header=None)
x_test = np.array(test_df.iloc[:,:-1])
y_test = np.array(test_df.iloc[:,-1])

# %%
y_trainTensor = torch.from_numpy(y_train)
y_testTensor = torch.from_numpy(y_test)
x_trainTensor = torch.from_numpy(np.asarray(x_train).astype(np.float32))
x_testTensor = torch.from_numpy(np.asarray(x_test).astype(np.float32))

# %%
train_data = TensorDataset(x_trainTensor, y_trainTensor)
train_loader = DataLoader(train_data,batch_size=12, shuffle=True)
test_data = TensorDataset(x_testTensor, y_testTensor)
test_loader = DataLoader(test_data,batch_size=12, shuffle=False)

# %%
depths = [3, 5, 9]
widths = [5, 10, 25, 50, 100]
parameter_type = [['tanh', 'xavier'], ['relu', 'he']]
epoch = 10

# %%
depths = [3, 5, 9]
widths = [5, 10, 25, 50, 100]
init_params = [['tanh', 'xavier'], ['relu', 'he']]
epoch = 10

for (act, init) in parameter_type:
    for depth in depths:
        for width in widths:
            print('Depth:', depth, ', Widths:', width, ', Activation_function:', act, ', Initialization_type:', init)
            model = NN(4, 2,  width, depth, act, init)
            optimizer = torch.optim.Adam(model.parameters())
            criterion = torch.nn.CrossEntropyLoss()
            train_loss = 0
            test_loss = 0
            for epoch in range(1, epoch + 1):
                train_loss += train(model, optimizer, criterion, train_loader, epoch)
                test_loss += test(model, test_loader, epoch)

            print('train_loss: {:.6f}'.format(train_loss))
            print('test_loss: {:.6f}'.format(test_loss))
# Out:
# Depth: 3 , Widths: 5 , Activation_function: tanh , Initialization_type: xavier
# Linear(in_features=4, out_features=5, bias=True)
# Tanh()
# Linear(in_features=5, out_features=5, bias=True)
# Tanh()
# Linear(in_features=5, out_features=2, bias=True)
# Tanh()
# Sequential(
#   (0): Linear(in_features=4, out_features=5, bias=True)
#   (1): Tanh()
#   (2): Linear(in_features=5, out_features=5, bias=True)
#   (3): Tanh()
#   (4): Linear(in_features=5, out_features=2, bias=True)
#   (5): Tanh()
# )
# train_loss: 2.918407
# test_loss: 2.730164
# Depth: 3 , Widths: 10 , Activation_function: tanh , Initialization_type: xavier
# Linear(in_features=4, out_features=10, bias=True)
# Tanh()
# Linear(in_features=10, out_features=10, bias=True)
# Tanh()
# Linear(in_features=10, out_features=2, bias=True)
# Tanh()
# Sequential(
#   (0): Linear(in_features=4, out_features=10, bias=True)
#   (1): Tanh()
#   (2): Linear(in_features=10, out_features=10, bias=True)
#   (3): Tanh()
#   (4): Linear(in_features=10, out_features=2, bias=True)
#   (5): Tanh()
# )
# train_loss: 2.758372
# test_loss: 2.530195
# Depth: 3 , Widths: 25 , Activation_function: tanh , Initialization_type: xavier
# Linear(in_features=4, out_features=25, bias=True)
# Tanh()
# Linear(in_features=25, out_features=25, bias=True)
# Tanh()
# Linear(in_features=25, out_features=2, bias=True)
# Tanh()
# Sequential(
#   (0): Linear(in_features=4, out_features=25, bias=True)
#   (1): Tanh()
#   (2): Linear(in_features=25, out_features=25, bias=True)
#   (3): Tanh()
#   (4): Linear(in_features=25, out_features=2, bias=True)
#   (5): Tanh()
# )
# train_loss: 1.955414
# test_loss: 1.670037
# Depth: 3 , Widths: 50 , Activation_function: tanh , Initialization_type: xavier
# Linear(in_features=4, out_features=50, bias=True)
# Tanh()
# Linear(in_features=50, out_features=50, bias=True)
# Tanh()
# Linear(in_features=50, out_features=2, bias=True)
# Tanh()
# Sequential(
#   (0): Linear(in_features=4, out_features=50, bias=True)
#   (1): Tanh()
#   (2): Linear(in_features=50, out_features=50, bias=True)
#   (3): Tanh()
#   (4): Linear(in_features=50, out_features=2, bias=True)
#   (5): Tanh()
# )
# train_loss: 1.451097
# test_loss: 1.353368
# Depth: 3 , Widths: 100 , Activation_function: tanh , Initialization_type: xavier
# Linear(in_features=4, out_features=100, bias=True)
# Tanh()
# Linear(in_features=100, out_features=100, bias=True)
# Tanh()
# Linear(in_features=100, out_features=2, bias=True)
# Tanh()
# Sequential(
#   (0): Linear(in_features=4, out_features=100, bias=True)
#   (1): Tanh()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): Tanh()
#   (4): Linear(in_features=100, out_features=2, bias=True)
#   (5): Tanh()
# )
# train_loss: 1.441609
# test_loss: 1.347984
# Depth: 5 , Widths: 5 , Activation_function: tanh , Initialization_type: xavier
# Linear(in_features=4, out_features=5, bias=True)
# Tanh()
# Linear(in_features=5, out_features=5, bias=True)
# Tanh()
# Linear(in_features=5, out_features=5, bias=True)
# Tanh()
# Linear(in_features=5, out_features=5, bias=True)
# Tanh()
# Linear(in_features=5, out_features=2, bias=True)
# Tanh()
# Sequential(
#   (0): Linear(in_features=4, out_features=5, bias=True)
#   (1): Tanh()
#   (2): Linear(in_features=5, out_features=5, bias=True)
#   (3): Tanh()
#   (4): Linear(in_features=5, out_features=5, bias=True)
#   (5): Tanh()
#   (6): Linear(in_features=5, out_features=5, bias=True)
#   (7): Tanh()
#   (8): Linear(in_features=5, out_features=2, bias=True)
#   (9): Tanh()
# )
# train_loss: 2.833253
# test_loss: 2.660218
# Depth: 5 , Widths: 10 , Activation_function: tanh , Initialization_type: xavier
# Linear(in_features=4, out_features=10, bias=True)
# Tanh()
# Linear(in_features=10, out_features=10, bias=True)
# Tanh()
# Linear(in_features=10, out_features=10, bias=True)
# Tanh()
# Linear(in_features=10, out_features=10, bias=True)
# Tanh()
# Linear(in_features=10, out_features=2, bias=True)
# Tanh()
# Sequential(
#   (0): Linear(in_features=4, out_features=10, bias=True)
#   (1): Tanh()
#   (2): Linear(in_features=10, out_features=10, bias=True)
#   (3): Tanh()
#   (4): Linear(in_features=10, out_features=10, bias=True)
#   (5): Tanh()
#   (6): Linear(in_features=10, out_features=10, bias=True)
#   (7): Tanh()
#   (8): Linear(in_features=10, out_features=2, bias=True)
#   (9): Tanh()
# )
# train_loss: 2.145623
# test_loss: 1.883295
# Depth: 5 , Widths: 25 , Activation_function: tanh , Initialization_type: xavier
# Linear(in_features=4, out_features=25, bias=True)
# Tanh()
# Linear(in_features=25, out_features=25, bias=True)
# Tanh()
# Linear(in_features=25, out_features=25, bias=True)
# Tanh()
# Linear(in_features=25, out_features=25, bias=True)
# Tanh()
# Linear(in_features=25, out_features=2, bias=True)
# Tanh()
# Sequential(
#   (0): Linear(in_features=4, out_features=25, bias=True)
#   (1): Tanh()
#   (2): Linear(in_features=25, out_features=25, bias=True)
#   (3): Tanh()
#   (4): Linear(in_features=25, out_features=25, bias=True)
#   (5): Tanh()
#   (6): Linear(in_features=25, out_features=25, bias=True)
#   (7): Tanh()
#   (8): Linear(in_features=25, out_features=2, bias=True)
#   (9): Tanh()
# )
# train_loss: 1.553916
# test_loss: 1.366671
# Depth: 5 , Widths: 50 , Activation_function: tanh , Initialization_type: xavier
# Linear(in_features=4, out_features=50, bias=True)
# Tanh()
# Linear(in_features=50, out_features=50, bias=True)
# Tanh()
# Linear(in_features=50, out_features=50, bias=True)
# Tanh()
# Linear(in_features=50, out_features=50, bias=True)
# Tanh()
# Linear(in_features=50, out_features=2, bias=True)
# Tanh()
# Sequential(
#   (0): Linear(in_features=4, out_features=50, bias=True)
#   (1): Tanh()
#   (2): Linear(in_features=50, out_features=50, bias=True)
#   (3): Tanh()
#   (4): Linear(in_features=50, out_features=50, bias=True)
#   (5): Tanh()
#   (6): Linear(in_features=50, out_features=50, bias=True)
#   (7): Tanh()
#   (8): Linear(in_features=50, out_features=2, bias=True)
#   (9): Tanh()
# )
# train_loss: 1.401805
# test_loss: 1.298306
# Depth: 5 , Widths: 100 , Activation_function: tanh , Initialization_type: xavier
# Linear(in_features=4, out_features=100, bias=True)
# Tanh()
# Linear(in_features=100, out_features=100, bias=True)
# Tanh()
# Linear(in_features=100, out_features=100, bias=True)
# Tanh()
# Linear(in_features=100, out_features=100, bias=True)
# Tanh()
# Linear(in_features=100, out_features=2, bias=True)
# Tanh()
# Sequential(
#   (0): Linear(in_features=4, out_features=100, bias=True)
#   (1): Tanh()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): Tanh()
#   (4): Linear(in_features=100, out_features=100, bias=True)
#   (5): Tanh()
#   (6): Linear(in_features=100, out_features=100, bias=True)
#   (7): Tanh()
#   (8): Linear(in_features=100, out_features=2, bias=True)
#   (9): Tanh()
# )
# train_loss: 1.370946
# test_loss: 1.304116
# Depth: 9 , Widths: 5 , Activation_function: tanh , Initialization_type: xavier
# Linear(in_features=4, out_features=5, bias=True)
# Tanh()
# Linear(in_features=5, out_features=5, bias=True)
# Tanh()
# Linear(in_features=5, out_features=5, bias=True)
# Tanh()
# Linear(in_features=5, out_features=5, bias=True)
# Tanh()
# Linear(in_features=5, out_features=5, bias=True)
# Tanh()
# Linear(in_features=5, out_features=5, bias=True)
# Tanh()
# Linear(in_features=5, out_features=5, bias=True)
# Tanh()
# Linear(in_features=5, out_features=5, bias=True)
# Tanh()
# Linear(in_features=5, out_features=2, bias=True)
# Tanh()
# Sequential(
#   (0): Linear(in_features=4, out_features=5, bias=True)
#   (1): Tanh()
#   (2): Linear(in_features=5, out_features=5, bias=True)
#   (3): Tanh()
#   (4): Linear(in_features=5, out_features=5, bias=True)
#   (5): Tanh()
#   (6): Linear(in_features=5, out_features=5, bias=True)
#   (7): Tanh()
#   (8): Linear(in_features=5, out_features=5, bias=True)
#   (9): Tanh()
#   (10): Linear(in_features=5, out_features=5, bias=True)
#   (11): Tanh()
#   (12): Linear(in_features=5, out_features=5, bias=True)
#   (13): Tanh()
#   (14): Linear(in_features=5, out_features=5, bias=True)
#   (15): Tanh()
#   (16): Linear(in_features=5, out_features=2, bias=True)
#   (17): Tanh()
# )
# train_loss: 2.711861
# test_loss: 2.514380
# Depth: 9 , Widths: 10 , Activation_function: tanh , Initialization_type: xavier
# Linear(in_features=4, out_features=10, bias=True)
# Tanh()
# Linear(in_features=10, out_features=10, bias=True)
# Tanh()
# Linear(in_features=10, out_features=10, bias=True)
# Tanh()
# Linear(in_features=10, out_features=10, bias=True)
# Tanh()
# Linear(in_features=10, out_features=10, bias=True)
# Tanh()
# Linear(in_features=10, out_features=10, bias=True)
# Tanh()
# Linear(in_features=10, out_features=10, bias=True)
# Tanh()
# Linear(in_features=10, out_features=10, bias=True)
# Tanh()
# Linear(in_features=10, out_features=2, bias=True)
# Tanh()
# Sequential(
#   (0): Linear(in_features=4, out_features=10, bias=True)
#   (1): Tanh()
#   (2): Linear(in_features=10, out_features=10, bias=True)
#   (3): Tanh()
#   (4): Linear(in_features=10, out_features=10, bias=True)
#   (5): Tanh()
#   (6): Linear(in_features=10, out_features=10, bias=True)
#   (7): Tanh()
#   (8): Linear(in_features=10, out_features=10, bias=True)
#   (9): Tanh()
#   (10): Linear(in_features=10, out_features=10, bias=True)
#   (11): Tanh()
#   (12): Linear(in_features=10, out_features=10, bias=True)
#   (13): Tanh()
#   (14): Linear(in_features=10, out_features=10, bias=True)
#   (15): Tanh()
#   (16): Linear(in_features=10, out_features=2, bias=True)
#   (17): Tanh()
# )
# train_loss: 1.817261
# test_loss: 1.595387
# Depth: 9 , Widths: 25 , Activation_function: tanh , Initialization_type: xavier
# Linear(in_features=4, out_features=25, bias=True)
# Tanh()
# Linear(in_features=25, out_features=25, bias=True)
# Tanh()
# Linear(in_features=25, out_features=25, bias=True)
# Tanh()
# Linear(in_features=25, out_features=25, bias=True)
# Tanh()
# Linear(in_features=25, out_features=25, bias=True)
# Tanh()
# Linear(in_features=25, out_features=25, bias=True)
# Tanh()
# Linear(in_features=25, out_features=25, bias=True)
# Tanh()
# Linear(in_features=25, out_features=25, bias=True)
# Tanh()
# Linear(in_features=25, out_features=2, bias=True)
# Tanh()
# Sequential(
#   (0): Linear(in_features=4, out_features=25, bias=True)
#   (1): Tanh()
#   (2): Linear(in_features=25, out_features=25, bias=True)
#   (3): Tanh()
#   (4): Linear(in_features=25, out_features=25, bias=True)
#   (5): Tanh()
#   (6): Linear(in_features=25, out_features=25, bias=True)
#   (7): Tanh()
#   (8): Linear(in_features=25, out_features=25, bias=True)
#   (9): Tanh()
#   (10): Linear(in_features=25, out_features=25, bias=True)
#   (11): Tanh()
#   (12): Linear(in_features=25, out_features=25, bias=True)
#   (13): Tanh()
#   (14): Linear(in_features=25, out_features=25, bias=True)
#   (15): Tanh()
#   (16): Linear(in_features=25, out_features=2, bias=True)
#   (17): Tanh()
# )
# train_loss: 1.432108
# test_loss: 1.312901
# Depth: 9 , Widths: 50 , Activation_function: tanh , Initialization_type: xavier
# Linear(in_features=4, out_features=50, bias=True)
# Tanh()
# Linear(in_features=50, out_features=50, bias=True)
# Tanh()
# Linear(in_features=50, out_features=50, bias=True)
# Tanh()
# Linear(in_features=50, out_features=50, bias=True)
# Tanh()
# Linear(in_features=50, out_features=50, bias=True)
# Tanh()
# Linear(in_features=50, out_features=50, bias=True)
# Tanh()
# Linear(in_features=50, out_features=50, bias=True)
# Tanh()
# Linear(in_features=50, out_features=50, bias=True)
# Tanh()
# Linear(in_features=50, out_features=2, bias=True)
# Tanh()
# Sequential(
#   (0): Linear(in_features=4, out_features=50, bias=True)
#   (1): Tanh()
#   (2): Linear(in_features=50, out_features=50, bias=True)
#   (3): Tanh()
#   (4): Linear(in_features=50, out_features=50, bias=True)
#   (5): Tanh()
#   (6): Linear(in_features=50, out_features=50, bias=True)
#   (7): Tanh()
#   (8): Linear(in_features=50, out_features=50, bias=True)
#   (9): Tanh()
#   (10): Linear(in_features=50, out_features=50, bias=True)
#   (11): Tanh()
#   (12): Linear(in_features=50, out_features=50, bias=True)
#   (13): Tanh()
#   (14): Linear(in_features=50, out_features=50, bias=True)
#   (15): Tanh()
#   (16): Linear(in_features=50, out_features=2, bias=True)
#   (17): Tanh()
# )
# train_loss: 1.363629
# test_loss: 1.281887
# Depth: 9 , Widths: 100 , Activation_function: tanh , Initialization_type: xavier
# Linear(in_features=4, out_features=100, bias=True)
# Tanh()
# Linear(in_features=100, out_features=100, bias=True)
# Tanh()
# Linear(in_features=100, out_features=100, bias=True)
# Tanh()
# Linear(in_features=100, out_features=100, bias=True)
# Tanh()
# Linear(in_features=100, out_features=100, bias=True)
# Tanh()
# Linear(in_features=100, out_features=100, bias=True)
# Tanh()
# Linear(in_features=100, out_features=100, bias=True)
# Tanh()
# Linear(in_features=100, out_features=100, bias=True)
# Tanh()
# Linear(in_features=100, out_features=2, bias=True)
# Tanh()
# Sequential(
#   (0): Linear(in_features=4, out_features=100, bias=True)
#   (1): Tanh()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): Tanh()
#   (4): Linear(in_features=100, out_features=100, bias=True)
#   (5): Tanh()
#   (6): Linear(in_features=100, out_features=100, bias=True)
#   (7): Tanh()
#   (8): Linear(in_features=100, out_features=100, bias=True)
#   (9): Tanh()
#   (10): Linear(in_features=100, out_features=100, bias=True)
#   (11): Tanh()
#   (12): Linear(in_features=100, out_features=100, bias=True)
#   (13): Tanh()
#   (14): Linear(in_features=100, out_features=100, bias=True)
#   (15): Tanh()
#   (16): Linear(in_features=100, out_features=2, bias=True)
#   (17): Tanh()
# )
# train_loss: 1.393614
# test_loss: 1.419584
# Depth: 3 , Widths: 5 , Activation_function: relu , Initialization_type: he
# Linear(in_features=4, out_features=5, bias=True)
# ReLU()
# Linear(in_features=5, out_features=5, bias=True)
# ReLU()
# Linear(in_features=5, out_features=2, bias=True)
# ReLU()
# Sequential(
#   (0): Linear(in_features=4, out_features=5, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=5, out_features=5, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=5, out_features=2, bias=True)
#   (5): ReLU()
# )
# train_loss: 5.467772
# test_loss: 5.330953
# Depth: 3 , Widths: 10 , Activation_function: relu , Initialization_type: he
# Linear(in_features=4, out_features=10, bias=True)
# ReLU()
# Linear(in_features=10, out_features=10, bias=True)
# ReLU()
# Linear(in_features=10, out_features=2, bias=True)
# ReLU()
# Sequential(
#   (0): Linear(in_features=4, out_features=10, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=10, out_features=10, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=10, out_features=2, bias=True)
#   (5): ReLU()
# )
# train_loss: 1.317912
# test_loss: 1.088519
# Depth: 3 , Widths: 25 , Activation_function: relu , Initialization_type: he
# Linear(in_features=4, out_features=25, bias=True)
# ReLU()
# Linear(in_features=25, out_features=25, bias=True)
# ReLU()
# Linear(in_features=25, out_features=2, bias=True)
# ReLU()
# Sequential(
#   (0): Linear(in_features=4, out_features=25, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=25, out_features=25, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=25, out_features=2, bias=True)
#   (5): ReLU()
# )
# train_loss: 1.345009
# test_loss: 1.029793
# Depth: 3 , Widths: 50 , Activation_function: relu , Initialization_type: he
# Linear(in_features=4, out_features=50, bias=True)
# ReLU()
# Linear(in_features=50, out_features=50, bias=True)
# ReLU()
# Linear(in_features=50, out_features=2, bias=True)
# ReLU()
# Sequential(
#   (0): Linear(in_features=4, out_features=50, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=50, out_features=50, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=50, out_features=2, bias=True)
#   (5): ReLU()
# )
# train_loss: 0.455865
# test_loss: 0.172489
# Depth: 3 , Widths: 100 , Activation_function: relu , Initialization_type: he
# Linear(in_features=4, out_features=100, bias=True)
# ReLU()
# Linear(in_features=100, out_features=100, bias=True)
# ReLU()
# Linear(in_features=100, out_features=2, bias=True)
# ReLU()
# Sequential(
#   (0): Linear(in_features=4, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=2, bias=True)
#   (5): ReLU()
# )
# train_loss: 0.252619
# test_loss: 0.049990
# Depth: 5 , Widths: 5 , Activation_function: relu , Initialization_type: he
# Linear(in_features=4, out_features=5, bias=True)
# ReLU()
# Linear(in_features=5, out_features=5, bias=True)
# ReLU()
# Linear(in_features=5, out_features=5, bias=True)
# ReLU()
# Linear(in_features=5, out_features=5, bias=True)
# ReLU()
# Linear(in_features=5, out_features=2, bias=True)
# ReLU()
# Sequential(
#   (0): Linear(in_features=4, out_features=5, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=5, out_features=5, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=5, out_features=5, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=5, out_features=5, bias=True)
#   (7): ReLU()
#   (8): Linear(in_features=5, out_features=2, bias=True)
#   (9): ReLU()
# )
# train_loss: 8.058847
# test_loss: 7.240319
# Depth: 5 , Widths: 10 , Activation_function: relu , Initialization_type: he
# Linear(in_features=4, out_features=10, bias=True)
# ReLU()
# Linear(in_features=10, out_features=10, bias=True)
# ReLU()
# Linear(in_features=10, out_features=10, bias=True)
# ReLU()
# Linear(in_features=10, out_features=10, bias=True)
# ReLU()
# Linear(in_features=10, out_features=2, bias=True)
# ReLU()
# Sequential(
#   (0): Linear(in_features=4, out_features=10, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=10, out_features=10, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=10, out_features=10, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=10, out_features=10, bias=True)
#   (7): ReLU()
#   (8): Linear(in_features=10, out_features=2, bias=True)
#   (9): ReLU()
# )
# train_loss: 3.357907
# test_loss: 3.159387
# Depth: 5 , Widths: 25 , Activation_function: relu , Initialization_type: he
# Linear(in_features=4, out_features=25, bias=True)
# ReLU()
# Linear(in_features=25, out_features=25, bias=True)
# ReLU()
# Linear(in_features=25, out_features=25, bias=True)
# ReLU()
# Linear(in_features=25, out_features=25, bias=True)
# ReLU()
# Linear(in_features=25, out_features=2, bias=True)
# ReLU()
# Sequential(
#   (0): Linear(in_features=4, out_features=25, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=25, out_features=25, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=25, out_features=25, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=25, out_features=25, bias=True)
#   (7): ReLU()
#   (8): Linear(in_features=25, out_features=2, bias=True)
#   (9): ReLU()
# )
# train_loss: 1.181132
# test_loss: 0.652614
# Depth: 5 , Widths: 50 , Activation_function: relu , Initialization_type: he
# Linear(in_features=4, out_features=50, bias=True)
# ReLU()
# Linear(in_features=50, out_features=50, bias=True)
# ReLU()
# Linear(in_features=50, out_features=50, bias=True)
# ReLU()
# Linear(in_features=50, out_features=50, bias=True)
# ReLU()
# Linear(in_features=50, out_features=2, bias=True)
# ReLU()
# Sequential(
#   (0): Linear(in_features=4, out_features=50, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=50, out_features=50, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=50, out_features=50, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=50, out_features=50, bias=True)
#   (7): ReLU()
#   (8): Linear(in_features=50, out_features=2, bias=True)
#   (9): ReLU()
# )
# train_loss: 0.493249
# test_loss: 0.097143
# Depth: 5 , Widths: 100 , Activation_function: relu , Initialization_type: he
# Linear(in_features=4, out_features=100, bias=True)
# ReLU()
# Linear(in_features=100, out_features=100, bias=True)
# ReLU()
# Linear(in_features=100, out_features=100, bias=True)
# ReLU()
# Linear(in_features=100, out_features=100, bias=True)
# ReLU()
# Linear(in_features=100, out_features=2, bias=True)
# ReLU()
# Sequential(
#   (0): Linear(in_features=4, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=100, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=100, out_features=100, bias=True)
#   (7): ReLU()
#   (8): Linear(in_features=100, out_features=2, bias=True)
#   (9): ReLU()
# )
# train_loss: 0.310387
# test_loss: 0.125504
# Depth: 9 , Widths: 5 , Activation_function: relu , Initialization_type: he
# Linear(in_features=4, out_features=5, bias=True)
# ReLU()
# Linear(in_features=5, out_features=5, bias=True)
# ReLU()
# Linear(in_features=5, out_features=5, bias=True)
# ReLU()
# Linear(in_features=5, out_features=5, bias=True)
# ReLU()
# Linear(in_features=5, out_features=5, bias=True)
# ReLU()
# Linear(in_features=5, out_features=5, bias=True)
# ReLU()
# Linear(in_features=5, out_features=5, bias=True)
# ReLU()
# Linear(in_features=5, out_features=5, bias=True)
# ReLU()
# Linear(in_features=5, out_features=2, bias=True)
# ReLU()
# Sequential(
#   (0): Linear(in_features=4, out_features=5, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=5, out_features=5, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=5, out_features=5, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=5, out_features=5, bias=True)
#   (7): ReLU()
#   (8): Linear(in_features=5, out_features=5, bias=True)
#   (9): ReLU()
#   (10): Linear(in_features=5, out_features=5, bias=True)
#   (11): ReLU()
#   (12): Linear(in_features=5, out_features=5, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=5, out_features=5, bias=True)
#   (15): ReLU()
#   (16): Linear(in_features=5, out_features=2, bias=True)
#   (17): ReLU()
# )
# train_loss: 1.571344
# test_loss: 1.256130
# Depth: 9 , Widths: 10 , Activation_function: relu , Initialization_type: he
# Linear(in_features=4, out_features=10, bias=True)
# ReLU()
# Linear(in_features=10, out_features=10, bias=True)
# ReLU()
# Linear(in_features=10, out_features=10, bias=True)
# ReLU()
# Linear(in_features=10, out_features=10, bias=True)
# ReLU()
# Linear(in_features=10, out_features=10, bias=True)
# ReLU()
# Linear(in_features=10, out_features=10, bias=True)
# ReLU()
# Linear(in_features=10, out_features=10, bias=True)
# ReLU()
# Linear(in_features=10, out_features=10, bias=True)
# ReLU()
# Linear(in_features=10, out_features=2, bias=True)
# ReLU()
# Sequential(
#   (0): Linear(in_features=4, out_features=10, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=10, out_features=10, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=10, out_features=10, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=10, out_features=10, bias=True)
#   (7): ReLU()
#   (8): Linear(in_features=10, out_features=10, bias=True)
#   (9): ReLU()
#   (10): Linear(in_features=10, out_features=10, bias=True)
#   (11): ReLU()
#   (12): Linear(in_features=10, out_features=10, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=10, out_features=10, bias=True)
#   (15): ReLU()
#   (16): Linear(in_features=10, out_features=2, bias=True)
#   (17): ReLU()
# )
# train_loss: 2.178664
# test_loss: 1.646671
# Depth: 9 , Widths: 25 , Activation_function: relu , Initialization_type: he
# Linear(in_features=4, out_features=25, bias=True)
# ReLU()
# Linear(in_features=25, out_features=25, bias=True)
# ReLU()
# Linear(in_features=25, out_features=25, bias=True)
# ReLU()
# Linear(in_features=25, out_features=25, bias=True)
# ReLU()
# Linear(in_features=25, out_features=25, bias=True)
# ReLU()
# Linear(in_features=25, out_features=25, bias=True)
# ReLU()
# Linear(in_features=25, out_features=25, bias=True)
# ReLU()
# Linear(in_features=25, out_features=25, bias=True)
# ReLU()
# Linear(in_features=25, out_features=2, bias=True)
# ReLU()
# Sequential(
#   (0): Linear(in_features=4, out_features=25, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=25, out_features=25, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=25, out_features=25, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=25, out_features=25, bias=True)
#   (7): ReLU()
#   (8): Linear(in_features=25, out_features=25, bias=True)
#   (9): ReLU()
#   (10): Linear(in_features=25, out_features=25, bias=True)
#   (11): ReLU()
#   (12): Linear(in_features=25, out_features=25, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=25, out_features=25, bias=True)
#   (15): ReLU()
#   (16): Linear(in_features=25, out_features=2, bias=True)
#   (17): ReLU()
# )
# train_loss: 6.933213
# test_loss: 6.931476
# Depth: 9 , Widths: 50 , Activation_function: relu , Initialization_type: he
# Linear(in_features=4, out_features=50, bias=True)
# ReLU()
# Linear(in_features=50, out_features=50, bias=True)
# ReLU()
# Linear(in_features=50, out_features=50, bias=True)
# ReLU()
# Linear(in_features=50, out_features=50, bias=True)
# ReLU()
# Linear(in_features=50, out_features=50, bias=True)
# ReLU()
# Linear(in_features=50, out_features=50, bias=True)
# ReLU()
# Linear(in_features=50, out_features=50, bias=True)
# ReLU()
# Linear(in_features=50, out_features=50, bias=True)
# ReLU()
# Linear(in_features=50, out_features=2, bias=True)
# ReLU()
# Sequential(
#   (0): Linear(in_features=4, out_features=50, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=50, out_features=50, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=50, out_features=50, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=50, out_features=50, bias=True)
#   (7): ReLU()
#   (8): Linear(in_features=50, out_features=50, bias=True)
#   (9): ReLU()
#   (10): Linear(in_features=50, out_features=50, bias=True)
#   (11): ReLU()
#   (12): Linear(in_features=50, out_features=50, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=50, out_features=50, bias=True)
#   (15): ReLU()
#   (16): Linear(in_features=50, out_features=2, bias=True)
#   (17): ReLU()
# )
# train_loss: 0.261778
# test_loss: 0.035110
# Depth: 9 , Widths: 100 , Activation_function: relu , Initialization_type: he
# Linear(in_features=4, out_features=100, bias=True)
# ReLU()
# Linear(in_features=100, out_features=100, bias=True)
# ReLU()
# Linear(in_features=100, out_features=100, bias=True)
# ReLU()
# Linear(in_features=100, out_features=100, bias=True)
# ReLU()
# Linear(in_features=100, out_features=100, bias=True)
# ReLU()
# Linear(in_features=100, out_features=100, bias=True)
# ReLU()
# Linear(in_features=100, out_features=100, bias=True)
# ReLU()
# Linear(in_features=100, out_features=100, bias=True)
# ReLU()
# Linear(in_features=100, out_features=2, bias=True)
# ReLU()
# Sequential(
#   (0): Linear(in_features=4, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=100, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=100, out_features=100, bias=True)
#   (7): ReLU()
#   (8): Linear(in_features=100, out_features=100, bias=True)
#   (9): ReLU()
#   (10): Linear(in_features=100, out_features=100, bias=True)
#   (11): ReLU()
#   (12): Linear(in_features=100, out_features=100, bias=True)
#   (13): ReLU()
#   (14): Linear(in_features=100, out_features=100, bias=True)
#   (15): ReLU()
#   (16): Linear(in_features=100, out_features=2, bias=True)
#   (17): ReLU()
# )
# train_loss: 0.268911
# test_loss: 0.176151
